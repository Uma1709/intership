# %% [markdown]
# <a href="https://colab.research.google.com/github/Uma1709/intership/blob/main/face_mask_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import libraries that I will use.
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# For preparing
import xml.etree.cElementTree as ET
import glob
import os
import json
import random
import shutil

from PIL import Image, ImageOps

# %%
with open('/content/drive/MyDrive/interships datasts(audio)/maksssksksss9.xml') as f:
    contents = f.read()
    print(contents)
# Out:
# <annotation>
#     <folder>images</folder>
#     <filename>maksssksksss9.png</filename>
#     <size>
#         <width>267</width>
#         <height>400</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>mask_weared_incorrect</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>148</xmin>
#             <ymin>75</ymin>
#             <xmax>201</xmax>
#             <ymax>133</ymax>
#         </bndbox>
#     </object>
#     <object>
#         <name>without_mask</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>27</xmin>
#             <ymin>78</ymin>
#             <xmax>56</xmax>
#             <ymax>106</ymax>
#         </bndbox>
#     </object>
# </annotation>

# %%
from PIL import Image

# %%
pip install pillow

# %%
Image.open("/content/drive/MyDrive/interships datasts(audio)/maksssksksss7.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x300 at 0x7B43494A7F10>

# %%
Image.open("/content/drive/MyDrive/interships datasts(audio)/maksssksksss18.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x267 at 0x7B43494A5C00>

# %%
Image.open("/content/drive/MyDrive/interships datasts(audio)/maksssksksss20.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=267x400 at 0x7B43494A6C50>

# %%
from PIL import Image, ImageOps

# creating an Image object
im1 = Image.open(r"/content/drive/MyDrive/interships datasts(audio)/maksssksksss20.png")

# applying grayscale method
im2 = ImageOps.grayscale(im1)

# You can display the grayscale image using the show() method
im2.show()
# Out:
# <PIL.Image.Image image mode=L size=267x400 at 0x7B4335719270>

# %%
with open('/content/drive/MyDrive/interships datasts(audio)/maksssksksss8.xml') as f:
    contents = f.read()
    print(contents)
# Out:
# <annotation>
#     <folder>images</folder>
#     <filename>maksssksksss8.png</filename>
#     <size>
#         <width>301</width>
#         <height>400</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>with_mask</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>75</xmin>
#             <ymin>271</ymin>
#             <xmax>152</xmax>
#             <ymax>385</ymax>
#         </bndbox>
#     </object>
# </annotation>
